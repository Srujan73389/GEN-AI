# %%
print('SRUJAN KANAKA')
# Out:
# SRUJAN KANAKA

# %%
import os
from dotenv import load_dotenv

# %%
import pandas as pd

# %% [markdown]
# ChatCompletion API and Completion API
# - Completion API: Hooks up with text completions from a single prompt.
# - Chat Completion API: Nails it in the chat game, keeping the conversational flow intact.

# %% [markdown]
# from dotenv import load_dotenv
# import os
# from openai import OpenAI
#
# load_dotenv()
#
# client = OpenAI(
#     api_key=os.getenv("GROQ_API_KEY"),
#     base_url="https://api.groq.com/openai/v1"
# )

# %%
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "system", "content": "You are a helpful AI assistant."},
        {"role": "user", "content": "Hello, what is ur name?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm doing great, thanks for asking. How can I assist you today?
